# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(tips["total_bill"], kde=False,bins=40)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.jointplot(x='total_bill', y='tip', data=tips,kind='hex')

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.rugplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
#plot the sum of the basic functions
import numpy as np
dataset = np.random.randn(25)
#set up x axis
x_min= dataset.min()
x_max= dataset.max()
# Create a random rugplot
sns.rugplot(dataset)
x_axis = np.linspace(x_min, x_max,100)
#create an empty kernel list
kernel_list = []
for data_point in dataset:
    #create a kernel for each point and append it to a list
    kernel = stats.norms(data_point,bandwidth).pdf(x_axis)
sum_of_kde = np.sum(kernel_list,axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 9
#       7 # Create a random rugplot
#       8 sns.rugplot(dataset)
# ----> 9 x_axis = np.linspace()
#      10 #create an empty kernel list
#      11 kernel_list = []
#
# TypeError: linspace() missing 2 required positional arguments: 'start' and 'stop'
